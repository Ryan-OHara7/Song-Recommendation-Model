# %%
import pandas as pd
import glob
import os

# Set the folder path where your CSVs are
folder_path = "Playlists"

# Use glob to get all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Read and combine them into one DataFrame
df_list = [pd.read_csv(file) for file in csv_files]
combined_df = pd.concat(df_list, ignore_index=True)

combined_df
# Out:
#         #                                             Song  \
# 0       1  Sweet Dreams (Are Made of This) - 2005 Remaster
# 1       2                                    Smalltown Boy
# 2       3                               I'm Still Standing
# 3       4                                       Funky Town
# 4       5                                   I'm So Excited
# ...   ...                                              ...
# 8681  403                                      Super Freak
# 8682  404                                  Time After Time
# 8683  405                                  Rock Me Amadeus
# 8684  406                                      Wicked Game
# 8685  407                        If I Could Turn Back Time
#
#                                     Artist  Popularity  BPM  \
# 0     Eurythmics,Annie Lennox,Dave Stewart          85  125
# 1                             Bronski Beat           3  135
# 2                               Elton John           6  177
# 3                               Lipps Inc.           6  122
# 4                      The Pointer Sisters          65   92
# ...                                    ...         ...  ...
# 8681                            Rick James          75  132
# 8682                          Cyndi Lauper          72  130
# 8683                                 Falco          68  177
# 8684                           Chris Isaak           2  113
# 8685                                  Cher          75  108
#
#                     Genres          Parent Genres  \
# 0     new wave, synthpop,   Pop, Rock, Electronic
# 1         synthpop, hi-nrg        Electronic, Pop
# 2                      NaN                    NaN
# 3                    disco                    Pop
# 4                    disco                    Pop
# ...                    ...                    ...
# 8681   funk, motown, disco               Pop, R&B
# 8682                   NaN                    NaN
# 8683   neue deutsche welle              Pop, Rock
# 8684                   NaN                    NaN
# 8685                   NaN                    NaN
#
#                                                   Album  Album Date   Time  \
# 0                       Sweet Dreams (Are Made Of This)  1983-01-04  03:36
# 1                                    The Age Of Consent  1984-00-00  05:03
# 2                           Rocket Man (Deluxe Edition)  2007-03-26  03:01
# 3                                     Paradas Continuas  2009-10-20  03:59
# 4                                               Best Of  1989-10-21  03:49
# ...                                                 ...         ...    ...
# 8681                      Street Songs (Deluxe Edition)  1981-04-07  03:25
# 8682  She's So Unusual: A 30th Anniversary Celebrati...  2014-03-28  04:03
# 8683                                            Falco 3  1985-02-19  03:22
# 8684                   Best of Chris Isaak (Remastered)  2006-00-00  04:46
# 8685                                     Heart Of Stone  1989-01-01  03:59
#
#       ...  Live  Loud (Db)          Key  Time Signature    Added At  \
# 0     ...    10         -7      C minor               4  2021-08-13
# 1     ...    20        -11        A#/B♭               4  2021-08-13
# 2     ...    30         -6  A#/B♭ minor               4  2021-08-13
# 3     ...    10         -8            C               4  2021-08-13
# 4     ...    10         -6        G#/A♭               4  2021-08-13
# ...   ...   ...        ...          ...             ...         ...
# 8681  ...     0         -8      A minor               4  2025-03-17
# 8682  ...     0         -9            C               4  2025-03-17
# 8683  ...     0         -9      E minor               4  2025-03-17
# 8684  ...     0         -8            A               4  2025-03-17
# 8685  ...    10        -10            B               4  2025-03-17
#
#             Spotify Track Id                  Album Label  Camelot  \
# 0     1TfqLAPs4K3s2rJMoCokcS            RCA Records Label       5A
# 1     0FrCX7P2C2hcRTcuhjEvK4            Rhino/London-Sire       6B
# 2     0lzpfrTARexLFXEACKSXTh        Universal Music Group       3A
# 3     7723JnKU2R15Iv4T7OJrly  CONSECUENCIAS DISCOGRAFICAS       8B
# 4     2u8MGAiS2hBVE7GZzTZLQI                       Ariola       4B
# ...                      ...                          ...      ...
# 8681  2dCmGcEOQrMQhMMS8Vj7Ca                       Motown       8A
# 8682  1Jj6MF0xDOMA3Ut2Z368Bx                  Epic/Legacy       8B
# 8683  0DfG1ltJnZyq4Tx3ZLL7ZU                       Ariola       9A
# 8684  390AWnOn2rfe9FzQjYmxIH             Mailboat Records      11B
# 8685  6mYrhCAGWzTdF8QnKuchXM                       Geffen       1B
#
#               ISRC  Time
# 0     GBARL0300589    NaN
# 1     GBAAP0200005    NaN
# 2     GBALX8300190    NaN
# 3     MX1900900138    NaN
# 4     USRC18203285    NaN
# ...            ...    ...
# 8681  USMO18100048    NaN
# 8682  USSM18300650    NaN
# 8683  ATB158500018    NaN
# 8684  USRE10601455    NaN
# 8685  USGF18923901    NaN
#
# [8686 rows x 26 columns]

# %%
# Count duplicates based on title and artist
duplicate_rows = combined_df.duplicated(subset=["Song", "Artist"]).sum()

print(f"🔎 Duplicate rows based on title and artist: {duplicate_rows}")
# Out:
# 🔎 Duplicate rows based on title and artist: 1867

# %%
clean_df = combined_df.drop_duplicates(subset=["Song", "Artist"], keep="first")

clean_df = clean_df.reset_index(drop=True)

clean_df
# Out:
#         #                                              Song  \
# 0       1   Sweet Dreams (Are Made of This) - 2005 Remaster
# 1       2                                     Smalltown Boy
# 2       3                                I'm Still Standing
# 3       4                                        Funky Town
# 4       5                                    I'm So Excited
# ...   ...                                               ...
# 6814  387  You're The First, The Last, My Everything - Edit
# 6815  388                                         Get It On
# 6816  395                     We Are Family - 1995 Remaster
# 6817  401                     Love Really Hurts Without You
# 6818  402                             I Can See Clearly Now
#
#                                     Artist  Popularity  BPM  \
# 0     Eurythmics,Annie Lennox,Dave Stewart          85  125
# 1                             Bronski Beat           3  135
# 2                               Elton John           6  177
# 3                               Lipps Inc.           6  122
# 4                      The Pointer Sisters          65   92
# ...                                    ...         ...  ...
# 6814                           Barry White          56  130
# 6815                                T. Rex          72  127
# 6816                         Sister Sledge          72  119
# 6817                           Billy Ocean           1  141
# 6818                           Johnny Nash          51  124
#
#                                      Genres          Parent Genres  \
# 0                      new wave, synthpop,   Pop, Rock, Electronic
# 1                          synthpop, hi-nrg        Electronic, Pop
# 2                                       NaN                    NaN
# 3                                     disco                    Pop
# 4                                     disco                    Pop
# ...                                     ...                    ...
# 6814  disco, soul, quiet storm, philly soul        Pop, R&B, Blues
# 6815                  glam rock, proto-punk                   Rock
# 6816                     disco, philly soul               Pop, R&B
# 6817                                    NaN                    NaN
# 6818                                    NaN                    NaN
#
#                                       Album  Album Date   Time  ...  Live  \
# 0           Sweet Dreams (Are Made Of This)  1983-01-04  03:36  ...    10
# 1                        The Age Of Consent  1984-00-00  05:03  ...    20
# 2               Rocket Man (Deluxe Edition)  2007-03-26  03:01  ...    30
# 3                         Paradas Continuas  2009-10-20  03:59  ...    10
# 4                                   Best Of  1989-10-21  03:49  ...    10
# ...                                     ...         ...    ...  ...   ...
# 6814                 All-Time Greatest Hits  1994-08-10  03:28  ...     0
# 6815                       Electric Warrior  1971-09-24  04:22  ...    60
# 6816          We Are Family (1995 Remaster)  1995-00-00  03:36  ...    20
# 6817  Here You Are: The Best of Billy Ocean  2016-04-29  02:58  ...    10
# 6818                 Radio Hits Of the '70s  2006-07-18  02:42  ...     0
#
#       Loud (Db)          Key  Time Signature    Added At  \
# 0            -7      C minor               4  2021-08-13
# 1           -11        A#/B♭               4  2021-08-13
# 2            -6  A#/B♭ minor               4  2021-08-13
# 3            -8            C               4  2021-08-13
# 4            -6        G#/A♭               4  2021-08-13
# ...         ...          ...             ...         ...
# 6814        -12            F               4  2025-03-17
# 6815         -7      B minor               4  2025-03-17
# 6816         -5      G minor               4  2025-03-17
# 6817         -4            F               4  2025-03-17
# 6818         -9            D               4  2025-03-17
#
#             Spotify Track Id                          Album Label  Camelot  \
# 0     1TfqLAPs4K3s2rJMoCokcS                    RCA Records Label       5A
# 1     0FrCX7P2C2hcRTcuhjEvK4                    Rhino/London-Sire       6B
# 2     0lzpfrTARexLFXEACKSXTh                Universal Music Group       3A
# 3     7723JnKU2R15Iv4T7OJrly          CONSECUENCIAS DISCOGRAFICAS       8B
# 4     2u8MGAiS2hBVE7GZzTZLQI                               Ariola       4B
# ...                      ...                                  ...      ...
# 6814  3rqXP37YkEnizabzjM7uIu                      Mercury Records       7B
# 6815  0LoQuiekvzqx7n8flgEKzF  Universal Music Group International      10A
# 6816  5IKLwqBQG6KU6MP2zP80Nu                       Rhino Atlantic       6A
# 6817  0nlVsRpZgsOZi0BFfzHSL9                        Sony Music CG       7B
# 6818  0oCT5rVvMdPPUm0bxG7yzT                    Legacy Recordings      10B
#
#               ISRC  Time
# 0     GBARL0300589    NaN
# 1     GBAAP0200005    NaN
# 2     GBALX8300190    NaN
# 3     MX1900900138    NaN
# 4     USRC18203285    NaN
# ...            ...    ...
# 6814  USPR37400014    NaN
# 6815  GBCHM7100038    NaN
# 6816  USAT20102166    NaN
# 6817  GBAHK9700121    NaN
# 6818  USSM10603310    NaN
#
# [6819 rows x 26 columns]

# %%
# Remove rows where the title contains 'remix' (case-insensitive)
filtered_df = clean_df[~clean_df['Song'].str.contains("remix", case=False, na=False)]

filtered_df = filtered_df.reset_index(drop=True)

filtered_df
# Out:
#         #                                              Song  \
# 0       1   Sweet Dreams (Are Made of This) - 2005 Remaster
# 1       2                                     Smalltown Boy
# 2       3                                I'm Still Standing
# 3       4                                        Funky Town
# 4       5                                    I'm So Excited
# ...   ...                                               ...
# 6655  387  You're The First, The Last, My Everything - Edit
# 6656  388                                         Get It On
# 6657  395                     We Are Family - 1995 Remaster
# 6658  401                     Love Really Hurts Without You
# 6659  402                             I Can See Clearly Now
#
#                                     Artist  Popularity  BPM  \
# 0     Eurythmics,Annie Lennox,Dave Stewart          85  125
# 1                             Bronski Beat           3  135
# 2                               Elton John           6  177
# 3                               Lipps Inc.           6  122
# 4                      The Pointer Sisters          65   92
# ...                                    ...         ...  ...
# 6655                           Barry White          56  130
# 6656                                T. Rex          72  127
# 6657                         Sister Sledge          72  119
# 6658                           Billy Ocean           1  141
# 6659                           Johnny Nash          51  124
#
#                                      Genres          Parent Genres  \
# 0                      new wave, synthpop,   Pop, Rock, Electronic
# 1                          synthpop, hi-nrg        Electronic, Pop
# 2                                       NaN                    NaN
# 3                                     disco                    Pop
# 4                                     disco                    Pop
# ...                                     ...                    ...
# 6655  disco, soul, quiet storm, philly soul        Pop, R&B, Blues
# 6656                  glam rock, proto-punk                   Rock
# 6657                     disco, philly soul               Pop, R&B
# 6658                                    NaN                    NaN
# 6659                                    NaN                    NaN
#
#                                       Album  Album Date   Time  ...  Live  \
# 0           Sweet Dreams (Are Made Of This)  1983-01-04  03:36  ...    10
# 1                        The Age Of Consent  1984-00-00  05:03  ...    20
# 2               Rocket Man (Deluxe Edition)  2007-03-26  03:01  ...    30
# 3                         Paradas Continuas  2009-10-20  03:59  ...    10
# 4                                   Best Of  1989-10-21  03:49  ...    10
# ...                                     ...         ...    ...  ...   ...
# 6655                 All-Time Greatest Hits  1994-08-10  03:28  ...     0
# 6656                       Electric Warrior  1971-09-24  04:22  ...    60
# 6657          We Are Family (1995 Remaster)  1995-00-00  03:36  ...    20
# 6658  Here You Are: The Best of Billy Ocean  2016-04-29  02:58  ...    10
# 6659                 Radio Hits Of the '70s  2006-07-18  02:42  ...     0
#
#       Loud (Db)          Key  Time Signature    Added At  \
# 0            -7      C minor               4  2021-08-13
# 1           -11        A#/B♭               4  2021-08-13
# 2            -6  A#/B♭ minor               4  2021-08-13
# 3            -8            C               4  2021-08-13
# 4            -6        G#/A♭               4  2021-08-13
# ...         ...          ...             ...         ...
# 6655        -12            F               4  2025-03-17
# 6656         -7      B minor               4  2025-03-17
# 6657         -5      G minor               4  2025-03-17
# 6658         -4            F               4  2025-03-17
# 6659         -9            D               4  2025-03-17
#
#             Spotify Track Id                          Album Label  Camelot  \
# 0     1TfqLAPs4K3s2rJMoCokcS                    RCA Records Label       5A
# 1     0FrCX7P2C2hcRTcuhjEvK4                    Rhino/London-Sire       6B
# 2     0lzpfrTARexLFXEACKSXTh                Universal Music Group       3A
# 3     7723JnKU2R15Iv4T7OJrly          CONSECUENCIAS DISCOGRAFICAS       8B
# 4     2u8MGAiS2hBVE7GZzTZLQI                               Ariola       4B
# ...                      ...                                  ...      ...
# 6655  3rqXP37YkEnizabzjM7uIu                      Mercury Records       7B
# 6656  0LoQuiekvzqx7n8flgEKzF  Universal Music Group International      10A
# 6657  5IKLwqBQG6KU6MP2zP80Nu                       Rhino Atlantic       6A
# 6658  0nlVsRpZgsOZi0BFfzHSL9                        Sony Music CG       7B
# 6659  0oCT5rVvMdPPUm0bxG7yzT                    Legacy Recordings      10B
#
#               ISRC  Time
# 0     GBARL0300589    NaN
# 1     GBAAP0200005    NaN
# 2     GBALX8300190    NaN
# 3     MX1900900138    NaN
# 4     USRC18203285    NaN
# ...            ...    ...
# 6655  USPR37400014    NaN
# 6656  GBCHM7100038    NaN
# 6657  USAT20102166    NaN
# 6658  GBAHK9700121    NaN
# 6659  USSM10603310    NaN
#
# [6660 rows x 26 columns]

# %%
columns_to_drop = ["Added At", "Spotify Track Id", "Album Label", "#", "ISRC", "Album Date", "Time ", "Album"]

# Drop them if they exist in the DataFrame
cleaner_df = filtered_df.drop(columns=[col for col in columns_to_drop if col in filtered_df.columns])

cleaner_df.columns
# Out:
# Index(['Song', 'Artist', 'Popularity', 'BPM', 'Genres', 'Parent Genres',
#        'Time', 'Dance', 'Energy', 'Acoustic', 'Instrumental', 'Happy',
#        'Speech', 'Live', 'Loud (Db)', 'Key', 'Time Signature', 'Camelot'],
#       dtype='object')

# %%
# List of artists to exclude from splitting by comma
exceptions = ["Tyler, The Creator", "Earth, Wind & Fire"]

def clean_artist(artist_name):
    if artist_name in exceptions:
        # Return artist name as-is (no split)
        return artist_name.strip()
    else:
        # Otherwise, split on first comma and take only first part as primary artist
        # (or you can adjust logic if you want a list of artists)
        return artist_name.split(",")[0].strip()

# Apply to your DataFrame
cleaner_df["Artist_Clean"] = cleaner_df["Artist"].apply(clean_artist)
cleaner_df["Song_Clean"] = cleaner_df["Song"].str.split(" - ").str[0]


cleaner_df
# Out:
#                                                   Song  \
# 0      Sweet Dreams (Are Made of This) - 2005 Remaster
# 1                                        Smalltown Boy
# 2                                   I'm Still Standing
# 3                                           Funky Town
# 4                                       I'm So Excited
# ...                                                ...
# 6655  You're The First, The Last, My Everything - Edit
# 6656                                         Get It On
# 6657                     We Are Family - 1995 Remaster
# 6658                     Love Really Hurts Without You
# 6659                             I Can See Clearly Now
#
#                                     Artist  Popularity  BPM  \
# 0     Eurythmics,Annie Lennox,Dave Stewart          85  125
# 1                             Bronski Beat           3  135
# 2                               Elton John           6  177
# 3                               Lipps Inc.           6  122
# 4                      The Pointer Sisters          65   92
# ...                                    ...         ...  ...
# 6655                           Barry White          56  130
# 6656                                T. Rex          72  127
# 6657                         Sister Sledge          72  119
# 6658                           Billy Ocean           1  141
# 6659                           Johnny Nash          51  124
#
#                                      Genres          Parent Genres   Time  \
# 0                      new wave, synthpop,   Pop, Rock, Electronic  03:36
# 1                          synthpop, hi-nrg        Electronic, Pop  05:03
# 2                                       NaN                    NaN  03:01
# 3                                     disco                    Pop  03:59
# 4                                     disco                    Pop  03:49
# ...                                     ...                    ...    ...
# 6655  disco, soul, quiet storm, philly soul        Pop, R&B, Blues  03:28
# 6656                  glam rock, proto-punk                   Rock  04:22
# 6657                     disco, philly soul               Pop, R&B  03:36
# 6658                                    NaN                    NaN  02:58
# 6659                                    NaN                    NaN  02:42
#
#       Dance  Energy  Acoustic  Instrumental  Happy  Speech  Live  Loud (Db)  \
# 0        69      71        23             0     88       0    10         -7
# 1        68      56        53             7     93       0    20        -11
# 2        49      93        46             0     79      10    30         -6
# 3        91      63         0            62     34       0    10         -8
# 4        69      86        10             0     69       0    10         -6
# ...     ...     ...       ...           ...    ...     ...   ...        ...
# 6655     63      59         0             0     93       0     0        -12
# 6656     73      88        18            86     91       0    60         -7
# 6657     78      89        30             0     82       0    20         -5
# 6658     52      91         0             0     96       0    10         -4
# 6659     68      53        41             0     58       0     0         -9
#
#               Key  Time Signature Camelot         Artist_Clean  \
# 0         C minor               4      5A           Eurythmics
# 1           A#/B♭               4      6B         Bronski Beat
# 2     A#/B♭ minor               4      3A           Elton John
# 3               C               4      8B           Lipps Inc.
# 4           G#/A♭               4      4B  The Pointer Sisters
# ...           ...             ...     ...                  ...
# 6655            F               4      7B          Barry White
# 6656      B minor               4     10A               T. Rex
# 6657      G minor               4      6A        Sister Sledge
# 6658            F               4      7B          Billy Ocean
# 6659            D               4     10B          Johnny Nash
#
#                                      Song_Clean
# 0               Sweet Dreams (Are Made of This)
# 1                                 Smalltown Boy
# 2                            I'm Still Standing
# 3                                    Funky Town
# 4                                I'm So Excited
# ...                                         ...
# 6655  You're The First, The Last, My Everything
# 6656                                  Get It On
# 6657                              We Are Family
# 6658              Love Really Hurts Without You
# 6659                      I Can See Clearly Now
#
# [6660 rows x 20 columns]

# %%
tyler_songs = cleaner_df[cleaner_df["Artist_Clean"] == "Tyler, The Creator"]
print(tyler_songs)
# Out:
#                         Song              Artist  Popularity  BPM Genres  \
# 1149  GONE, GONE / THANK YOU  Tyler, The Creator          79   79    NaN
# 1181                 Glitter  Tyler, The Creator          70   79    NaN
# 1415   ARE WE STILL FRIENDS?  Tyler, The Creator          86  187    NaN
# 1533                DOGTOOTH  Tyler, The Creator          12   78    NaN
# 4575              LUMBERJACK  Tyler, The Creator          66  171    NaN
# 4680                 I THINK  Tyler, The Creator          77  121    NaN
# 4684               EARFQUAKE  Tyler, The Creator          84   80    NaN
# 4754     RUNNING OUT OF TIME  Tyler, The Creator          79   84    NaN
# 4860          NEW MAGIC WAND  Tyler, The Creator          82  140    NaN
# 4864           BEST INTEREST  Tyler, The Creator          83   98    NaN
# 5127                    Noid  Tyler, The Creator          75   82    NaN
#
#      Parent Genres   Time  Dance  Energy  Acoustic  Instrumental  Happy  \
# 1149           NaN  06:15     52      49        22             0     47
# 1181           NaN  03:44     45      43        31             0     37
# 1415           NaN  04:25     22      50        13             0     31
# 1533           NaN  02:41     71      65        51             0     80
# 4575           NaN  02:18     39      76        12             0     43
# 4680           NaN  03:32     83      58         1             0     43
# 4684           NaN  03:10     55      50        23             0     41
# 4754           NaN  02:57     36      39        30             0     16
# 4860           NaN  03:15     62      73        10             0     46
# 4864           NaN  02:07     60      57         9             0     34
# 5127           NaN  04:44     38      78        52             0     42
#
#       Speech  Live  Loud (Db)          Key  Time Signature Camelot  \
# 1149      10    10         -8  A#/B♭ minor               4      3A
# 1181      20    60        -12        C♯/D♭               5      3B
# 1415       0    10         -8        A#/B♭               3      6B
# 1533      30    20         -6        G#/A♭               4      4B
# 4575      50    50         -6            A               4     11B
# 4680       0    10         -8  G#/A♭ minor               4      1A
# 4684       0    80         -9            A               4     11B
# 4754       0    10        -11        F#/G♭               4      2B
# 4860      10    60         -5      F minor               4      4A
# 4864       0    30         -8      B minor               3     10A
# 5127      30    40         -6        C♯/D♭               4      3B
#
#             Artist_Clean              Song_Clean
# 1149  Tyler, The Creator  GONE, GONE / THANK YOU
# 1181  Tyler, The Creator                 Glitter
# 1415  Tyler, The Creator   ARE WE STILL FRIENDS?
# 1533  Tyler, The Creator                DOGTOOTH
# 4575  Tyler, The Creator              LUMBERJACK
# 4680  Tyler, The Creator                 I THINK
# 4684  Tyler, The Creator               EARFQUAKE
# 4754  Tyler, The Creator     RUNNING OUT OF TIME
# 4860  Tyler, The Creator          NEW MAGIC WAND
# 4864  Tyler, The Creator           BEST INTEREST
# 5127  Tyler, The Creator                    Noid

# %%
cleaner_df.to_csv("initial_songs_master.csv", index=False)

# %% [markdown]
# ## BREAK: Scrape genres

# %%
# Load the CSV
genre_df = pd.read_csv("week_2_songs_with_genre_tags_full.csv")

# Get value counts for the 'Tag Source' column
tag_source_counts = genre_df["Tag Source"].value_counts()

# Display the result
print(tag_source_counts)
# Out:
# Tag Source
# track     5468
# none       687
# artist     505
# Name: count, dtype: int64

# %%
none_tags_df = genre_df[genre_df["Tag Source"] == "none"]

# Count how many times each artist appears in the "none" category
artist_none_counts = none_tags_df["Artist"].value_counts()

# Display the top artists with missing tags
print(artist_none_counts.head(20))
# Out:
# Artist
# Morgan Wallen          38
# Zach Bryan             16
# Royel Otis             12
# Wallows                 9
# JAWNY                   8
# Still Woozy             8
# Blxst,Bino Rideaux      7
# mazie                   7
# Blxst                   6
# Hunxho                  6
# Dominic Fike            6
# Mt. Joy                 5
# Noah Kahan              5
# Caamp                   5
# HARBOUR                 5
# The Backseat Lovers     5
# Kalan.FrFr              5
# Bailey Zimmerman        5
# Megan Moroney           4
# Disintegration C.E.     4
# Name: count, dtype: int64

# %%
artist_tags_df = genre_df[genre_df["Tag Source"] == "artist"]

# Count how many times each artist appears in the "none" category
artist_artist_counts = artist_tags_df["Artist"].value_counts()

# Display the top artists with missing tags
print(artist_artist_counts.head(20))
# Out:
# Artist
# DeJ Loaf,Jacquees    8
# K CAMP               5
# TroyBoi              5
# Thomas Rhett         4
# Joel McColl          3
# Christel Golden      3
# Olga Neff            3
# SRNDE                3
# Lil Durk             3
# PARTYNEXTDOOR        3
# Laura Bryna          2
# Chase Rice           2
# Dylan Scott          2
# The Lumineers        2
# Zach Bryan           2
# B3N&J8CUB            2
# Metallica            2
# Jon Pardi            2
# Nicky Romero         2
# Chris Stapleton      2
# Name: count, dtype: int64

# %%
track_tags_df = genre_df[genre_df["Tag Source"] == "track"]

# Count how many times each artist appears in the "none" category
artist_track_counts = track_tags_df["Artist"].value_counts()

# Display the top artists with missing tags
print(artist_track_counts.head(20))
# Out:
# Artist
# Drake                 51
# Taylor Swift          49
# Morgan Wallen         43
# The Weeknd            36
# The Beatles           32
# Bryson Tiller         27
# Luke Combs            26
# Billy Joel            24
# Fleetwood Mac         24
# Pink Floyd            23
# Wallows               23
# Bob Dylan             21
# Zach Bryan            20
# David Bowie           19
# The Rolling Stones    19
# The Beach Boys        18
# Elton John            18
# Travis Scott          17
# Coldplay              17
# Queen                 17
# Name: count, dtype: int64

# %%
# Keep only rows where Tag Source is 'track'
df_track_only = genre_df[genre_df["Tag Source"] == "track"]

# Optionally reset the index
df_track_only = df_track_only.reset_index(drop=True)

df_track_only
# Out:
#                                                   Song  \
# 0      Sweet Dreams (Are Made of This) - 2005 Remaster
# 1                                        Smalltown Boy
# 2                                   I'm Still Standing
# 3                                           Funky Town
# 4                                       I'm So Excited
# ...                                                ...
# 5463  You're The First, The Last, My Everything - Edit
# 5464                                         Get It On
# 5465                     We Are Family - 1995 Remaster
# 5466                     Love Really Hurts Without You
# 5467                             I Can See Clearly Now
#
#                                     Artist  \
# 0     Eurythmics,Annie Lennox,Dave Stewart
# 1                             Bronski Beat
# 2                               Elton John
# 3                               Lipps Inc.
# 4                      The Pointer Sisters
# ...                                    ...
# 5463                           Barry White
# 5464                                T. Rex
# 5465                         Sister Sledge
# 5466                           Billy Ocean
# 5467                           Johnny Nash
#
#                                            Genre Tags Tag Source
# 0     80s, pop, new wave, female vocalists, synth pop      track
# 1             80s, new wave, synthpop, pop, synth pop      track
# 2            pop, 80s, elton john, rock, classic rock      track
# 3                         Disco, 80s, pop, 70s, dance      track
# 4                        80s, Disco, pop, dance, soul      track
# ...                                               ...        ...
# 5463              soul, barry white, Disco, 70s, Love      track
# 5464         glam rock, 70s, classic rock, rock, glam      track
# 5465                    Disco, 70s, dance, funk, soul      track
# 5466                       80s, pop, soul, 70s, Disco      track
# 5467                   reggae, 70s, pop, oldies, soul      track
#
# [5468 rows x 4 columns]

# %%
# Save to a new CSV
df_track_only.to_csv("songs_genre_clean.csv", index=False)

# %% [markdown]
# ## BREAK: Scrape lyrics

# %%
df = pd.read_csv('week_2_songs_genre_lyrics.csv')

# Check how many rows have empty or missing lyrics
empty_lyrics = df[df['lyrics'].isna() | (df['lyrics'].str.strip() == '')]
print(f"Number of rows with empty lyrics: {len(empty_lyrics)}")

# Optionally preview them
print(empty_lyrics.head())
# Out:
# Number of rows with empty lyrics: 671
#                                                Song  \
# 0   Sweet Dreams (Are Made of This) - 2005 Remaster
# 15              Sisters Are Doin' It for Themselves
# 21         Flashdance...What a Feeling - Radio Edit
# 22         Got My Mind Set On You - Remastered 2004
# 29        Let's Dance - Single Version [Remastered]
#
#                                                Artist  \
# 0                Eurythmics,Annie Lennox,Dave Stewart
# 15  Eurythmics,Annie Lennox,Dave Stewart,Aretha Fr...
# 21                                         Irene Cara
# 22                                    George Harrison
# 29                                        David Bowie
#
#                                          Genre Tags Tag Source lyrics
# 0   80s, pop, new wave, female vocalists, synth pop      track    NaN
# 15       80s, pop, new wave, rock, female vocalists      track    NaN
# 21    80s, pop, Soundtrack, dance, female vocalists      track    NaN
# 22    classic rock, 80s, george harrison, rock, pop      track    NaN
# 29          80s, rock, classic rock, pop, glam rock      track    NaN

# %%
# Remove rows with empty or missing lyrics
df_cleaned = df[~(df['lyrics'].isna() | (df['lyrics'].str.strip() == ''))]

df_cleaned
# Out:
#                                 Song               Artist  \
# 1                      Smalltown Boy         Bronski Beat
# 2                 I'm Still Standing           Elton John
# 3                         Funky Town           Lipps Inc.
# 4                     I'm So Excited  The Pointer Sisters
# 5                   Cheri Cheri Lady       Modern Talking
# ...                              ...                  ...
# 5460  Rock with You - Single Version      Michael Jackson
# 5462                  You Sexy Thing        Hot Chocolate
# 5464                       Get It On               T. Rex
# 5466   Love Really Hurts Without You          Billy Ocean
# 5467           I Can See Clearly Now          Johnny Nash
#
#                                     Genre Tags Tag Source  \
# 1      80s, new wave, synthpop, pop, synth pop      track
# 2     pop, 80s, elton john, rock, classic rock      track
# 3                  Disco, 80s, pop, 70s, dance      track
# 4                 80s, Disco, pop, dance, soul      track
# 5       80s, Disco, pop, Modern Talking, dance      track
# ...                                        ...        ...
# 5460   pop, michael jackson, 80s, Disco, dance      track
# 5462               Disco, 70s, funk, soul, pop      track
# 5464  glam rock, 70s, classic rock, rock, glam      track
# 5466                80s, pop, soul, 70s, Disco      track
# 5467            reggae, 70s, pop, oldies, soul      track
#
#                                                  lyrics
# 1     To your soul\nTo your soul\nCry\nCry\nCry\n\nY...
# 2     You could never know what it's like\nYour bloo...
# 3     Gotta make a move to a town that's right for m...
# 4     Tonight's the night we're gonna make it happen...
# 5     Oh, I cannot explain\nEvery time, it's the sam...
# ...                                                 ...
# 5460  Girl, close your eyes\nLet that rhythm get int...
# 5462  I believe in miracles\nWhere're you from?\nYou...
# 5464  Well, you're dirty and sweet\nClad in black, d...
# 5466  You run around town like a fool and you think ...
# 5467  I can see clearly now the rain is gone\nI can ...
#
# [4797 rows x 5 columns]

# %%
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException

# Make language detection deterministic (same result every time)
DetectorFactory.seed = 0

# Function to detect language safely
def detect_language(text):
    try:
        return detect(text)
    except LangDetectException:
        return 'error'

# Apply to the lyrics column (this may take some time with 2000+ songs)
df_cleaned['language'] = df_cleaned['lyrics'].apply(detect_language)

# Check how many are not English
non_english_df = df_cleaned[df_cleaned['language'] != 'en']

# Show some examples
print(non_english_df[['Song', 'Artist', 'language', 'lyrics']])
# Out:
#                              Song                       Artist language  \
# 57                 99 Luftballons                         Nena       de
# 227               Rock Me Amadeus                        Falco       de
# 304                      Bamboléo                  Gipsy Kings       es
# 404                       Flicker              Porter Robinson       ja
# 417                            OK                       Madeon       sk
# ...                           ...                          ...      ...
# 5173                         Tusa          KAROL G,Nicki Minaj       es
# 5185                   Supalonely          BENEE,Gus Dapperton       tr
# 5193                      Dilemma          Nelly,Kelly Rowland       de
# 5253             Somethin' Stupid  Frank Sinatra,Nancy Sinatra       tr
# 5434  Never Had A Dream Come True                Stevie Wonder       pt
#
#                                                  lyrics
# 57    Hast du etwas Zeit für mich?\nDann singe ich e...
# 227   Rock me, rock me, rock me, rock me, rock me, A...
# 304   Este amor llega así de esta manera\nNo tiene l...
# 404   私はちょうど何が重要か\n私はちょうど何が重要か\n私はちょうど何が重要か\n見つけようとし...
# 417   Ok\n\nOk, ok, ok\nOk, such a\nOk, ok, ok, ok\n...
# ...                                                 ...
# 5173  O-O-Ovy On The Drums\nYa no tiene excusa\nHoy ...
# 5185  Biliyorum işleri berbat ettim, sadece ezik bir...
# 5193  Ah, ah\nCheck das, check das\nAh, ah, ah\n\nIc...
# 5253  Benimle bir akşam geçirmek için zamanın olduğu...
# 5434  Do do do do do do do do do\nDo do do\nDo do do...
#
# [300 rows x 4 columns]
# /var/folders/nf/jqpg66kx52z7vrjhxgwb3h480000gn/T/ipykernel_80458/1616219158.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['language'] = df_cleaned['lyrics'].apply(detect_language)

# %%
# Assuming the column used to match is 'title'
df_final = df_cleaned[~df_cleaned['Song'].isin(non_english_df['Song'])]

df_final = df_final.reset_index(drop=True)

df_final
# Out:
#                                 Song               Artist  \
# 0                      Smalltown Boy         Bronski Beat
# 1                 I'm Still Standing           Elton John
# 2                         Funky Town           Lipps Inc.
# 3                     I'm So Excited  The Pointer Sisters
# 4                   Cheri Cheri Lady       Modern Talking
# ...                              ...                  ...
# 4484  Rock with You - Single Version      Michael Jackson
# 4485                  You Sexy Thing        Hot Chocolate
# 4486                       Get It On               T. Rex
# 4487   Love Really Hurts Without You          Billy Ocean
# 4488           I Can See Clearly Now          Johnny Nash
#
#                                     Genre Tags Tag Source  \
# 0      80s, new wave, synthpop, pop, synth pop      track
# 1     pop, 80s, elton john, rock, classic rock      track
# 2                  Disco, 80s, pop, 70s, dance      track
# 3                 80s, Disco, pop, dance, soul      track
# 4       80s, Disco, pop, Modern Talking, dance      track
# ...                                        ...        ...
# 4484   pop, michael jackson, 80s, Disco, dance      track
# 4485               Disco, 70s, funk, soul, pop      track
# 4486  glam rock, 70s, classic rock, rock, glam      track
# 4487                80s, pop, soul, 70s, Disco      track
# 4488            reggae, 70s, pop, oldies, soul      track
#
#                                                  lyrics language
# 0     To your soul\nTo your soul\nCry\nCry\nCry\n\nY...       en
# 1     You could never know what it's like\nYour bloo...       en
# 2     Gotta make a move to a town that's right for m...       en
# 3     Tonight's the night we're gonna make it happen...       en
# 4     Oh, I cannot explain\nEvery time, it's the sam...       en
# ...                                                 ...      ...
# 4484  Girl, close your eyes\nLet that rhythm get int...       en
# 4485  I believe in miracles\nWhere're you from?\nYou...       en
# 4486  Well, you're dirty and sweet\nClad in black, d...       en
# 4487  You run around town like a fool and you think ...       en
# 4488  I can see clearly now the rain is gone\nI can ...       en
#
# [4489 rows x 6 columns]

# %%
master_df = pd.read_csv('week_2_initial_songs_master.csv')

# Merge Genre Tags and lyrics from df_final
# We'll assume the columns to join on are 'artist' and 'title'
columns_to_add = ['Artist', 'Song', 'Genre Tags', 'lyrics']  # adjust names if needed

# Ensure df_final has only the necessary columns
df_to_merge = df_final[columns_to_add]

# Perform the merge
merged_df = master_df.merge(df_to_merge, on=['Artist', 'Song'], how='left')

# %%
# Remove rows where lyrics are NaN or just whitespace
final_df = merged_df[~(merged_df['lyrics'].isna() | (merged_df['lyrics'].str.strip() == ''))]

# Reset index for cleanliness
final_df = final_df.reset_index(drop=True)

# %%
final_df = final_df.drop(columns=['Genres', 'Parent Genres', 'Time Signature'])

# %%
final_df
# Out:
#                                 Song               Artist  Popularity  BPM  \
# 0                      Smalltown Boy         Bronski Beat           3  135
# 1                 I'm Still Standing           Elton John           6  177
# 2                         Funky Town           Lipps Inc.           6  122
# 3                     I'm So Excited  The Pointer Sisters          65   92
# 4                   Cheri Cheri Lady       Modern Talking          82  114
# ...                              ...                  ...         ...  ...
# 4484  Rock with You - Single Version      Michael Jackson          82  114
# 4485                  You Sexy Thing        Hot Chocolate          75  106
# 4486                       Get It On               T. Rex          72  127
# 4487   Love Really Hurts Without You          Billy Ocean           1  141
# 4488           I Can See Clearly Now          Johnny Nash          51  124
#
#        Time  Dance  Energy  Acoustic  Instrumental  Happy  Speech  Live  \
# 0     05:03     68      56        53             7     93       0    20
# 1     03:01     49      93        46             0     79      10    30
# 2     03:59     91      63         0            62     34       0    10
# 3     03:49     69      86        10             0     69       0    10
# 4     03:46     68      62        46             1     85       0    30
# ...     ...    ...     ...       ...           ...    ...     ...   ...
# 4484  03:40     81      54        18             0     85       0    10
# 4485  04:04     79      73        52             0     96       0    10
# 4486  04:22     73      88        18            86     91       0    60
# 4487  02:58     52      91         0             0     96       0    10
# 4488  02:42     68      53        41             0     58       0     0
#
#       Loud (Db)          Key Camelot         Artist_Clean  \
# 0           -11        A#/B♭      6B         Bronski Beat
# 1            -6  A#/B♭ minor      3A           Elton John
# 2            -8            C      8B           Lipps Inc.
# 3            -6        G#/A♭      4B  The Pointer Sisters
# 4           -14        A#/B♭      6B       Modern Talking
# ...         ...          ...     ...                  ...
# 4484        -13        C♯/D♭      3B      Michael Jackson
# 4485         -5            F      7B        Hot Chocolate
# 4486         -7      B minor     10A               T. Rex
# 4487         -4            F      7B          Billy Ocean
# 4488         -9            D     10B          Johnny Nash
#
#                          Song_Clean                                Genre Tags  \
# 0                     Smalltown Boy   80s, new wave, synthpop, pop, synth pop
# 1                I'm Still Standing  pop, 80s, elton john, rock, classic rock
# 2                        Funky Town               Disco, 80s, pop, 70s, dance
# 3                    I'm So Excited              80s, Disco, pop, dance, soul
# 4                  Cheri Cheri Lady    80s, Disco, pop, Modern Talking, dance
# ...                             ...                                       ...
# 4484                  Rock with You   pop, michael jackson, 80s, Disco, dance
# 4485                 You Sexy Thing               Disco, 70s, funk, soul, pop
# 4486                      Get It On  glam rock, 70s, classic rock, rock, glam
# 4487  Love Really Hurts Without You                80s, pop, soul, 70s, Disco
# 4488          I Can See Clearly Now            reggae, 70s, pop, oldies, soul
#
#                                                  lyrics
# 0     To your soul\nTo your soul\nCry\nCry\nCry\n\nY...
# 1     You could never know what it's like\nYour bloo...
# 2     Gotta make a move to a town that's right for m...
# 3     Tonight's the night we're gonna make it happen...
# 4     Oh, I cannot explain\nEvery time, it's the sam...
# ...                                                 ...
# 4484  Girl, close your eyes\nLet that rhythm get int...
# 4485  I believe in miracles\nWhere're you from?\nYou...
# 4486  Well, you're dirty and sweet\nClad in black, d...
# 4487  You run around town like a fool and you think ...
# 4488  I can see clearly now the rain is gone\nI can ...
#
# [4489 rows x 19 columns]

# %%
final_df.to_csv('dataset.csv', index=False)
